# %%
import pandas as pd
import statistics as sts
from numpy import nan
from Funciones import fold_change

# %%
Genes1 = pd.read_csv('./Genes/genes-metabolismo.csv', header = None)
Genes2 = pd.read_csv('./Genes/genes-metabolismo.csv', header = None)
Genes3 = pd.read_excel('./Genes/genes2Nuevo.xlsx',header = None)
Genes = set(Genes1[0]).union(set(Genes2[0])).union(Genes3[0])

# %%
Data0 = pd.read_excel('GSE147507/GSE147507.xlsx')
Data0.index = list(Data0['Unnamed: 0'])
Data0.drop(columns = ['Unnamed: 0']+[_ for _ in list(Data0.columns) if _[6] in ['3','4','8']],
          inplace = True)
Data0.drop(columns = list(Data0.loc[:,'Series9_NHBE_IAV_1':'Series9_NHBE_IAV_4'])+list(Data0.loc[:,'Series9_NHBE_IAVdNS1_1':'Series9_NHBE_IAVdNS1_4']), 
          inplace = True )

# %%
Data = Data0.copy()

# %%
Total_Gen = len(Data.index)

# %%
for GAPDH,Columna in zip(list(Data.loc['GAPDH']),list(Data.columns)) :
    Data[Columna] = Data[Columna]/GAPDH

# %%
series_ids = ["1", "2", "5", "6", "7", "9", "15", "16"]
Series = {}

# %%
for id in series_ids:
    Series[id] = Data.loc[:,list(S for S in list(Data.columns) if f"Series{id}_" in S[:9])].copy()

# %%
for key in Series.keys():
    measurement_types = dict.fromkeys(map(lambda x: x[:-2], Series[key]))
    for typ in measurement_types.keys():
        Series[key][f"Promedio_{typ}"] = list(sts.mean(Series[key].filter(like=typ, axis=1).iloc[fila]) for fila in range (Total_Gen))

# %%
#fold-change
for key in Series.keys():
    # Remove else False
    measurement_types = [x for x in Series[key] if "Promedio" in x]
    if key != "15":
        mock = Series[key].filter(regex="^Promedio.*Mock$").columns[0]
    else:
        mock = Series[key].filter(regex="Promedio_Series15_HealthyLungBiopsy").columns[0]
    measurement_types.remove(mock)

    if len(measurement_types) > 1:
        for typ in measurement_types:
            name = typ.split(f"_Series{key}_")[1].replace("_", " ")
            Series[key][f"fold-change Series{key} {name}"] = fold_change(Series[key][mock], Series[key][typ])
    else:
        typ = measurement_types[0]
        Series[key][f"fold-change Series{key}"] = fold_change(Series[key][mock], Series[key][typ])

# %%
Series["9"]
# Out:
#            Series9_NHBE_Mock_1  Series9_NHBE_Mock_2  Series9_NHBE_Mock_3  \
# DDX11L1               0.000000             0.000000             0.000000
# WASH7P                0.001413             0.001365             0.001161
# FAM138A               0.000000             0.000000             0.000000
# FAM138F               0.000000             0.000000             0.000000
# OR4F5                 0.000000             0.000000             0.000000
# ...                        ...                  ...                  ...
# CDY1B                 0.000000             0.000000             0.000000
# CDY1                  0.000000             0.000000             0.000000
# CSPG4P1Y              0.000000             0.000000             0.000000
# GOLGA2P3Y             0.000000             0.000000             0.000000
# GOLGA2P2Y             0.000000             0.000000             0.000000
#
#            Series9_NHBE_Mock_4  Series9_NHBE_IFNB_4h_1  \
# DDX11L1               0.000000                 0.00000
# WASH7P                0.001172                 0.00092
# FAM138A               0.000000                 0.00000
# FAM138F               0.000000                 0.00000
# OR4F5                 0.000000                 0.00000
# ...                        ...                     ...
# CDY1B                 0.000000                 0.00000
# CDY1                  0.000000                 0.00000
# CSPG4P1Y              0.000000                 0.00000
# GOLGA2P3Y             0.000000                 0.00000
# GOLGA2P2Y             0.000000                 0.00000
#
#            Series9_NHBE_IFNB_4h_2  Series9_NHBE_IFNB_6h_1  \
# DDX11L1                   0.00000                0.000000
# WASH7P                    0.00086                0.000889
# FAM138A                   0.00000                0.000000
# FAM138F                   0.00000                0.000000
# OR4F5                     0.00000                0.000000
# ...                           ...                     ...
# CDY1B                     0.00000                0.000000
# CDY1                      0.00000                0.000000
# CSPG4P1Y                  0.00000                0.000000
# GOLGA2P3Y                 0.00000                0.000000
# GOLGA2P2Y                 0.00000                0.000000
#
#            Series9_NHBE_IFNB_6h_2  Series9_NHBE_IFNB_12h_1  \
# DDX11L1                  0.000000                 0.000000
# WASH7P                   0.000677                 0.000913
# FAM138A                  0.000000                 0.000000
# FAM138F                  0.000000                 0.000000
# OR4F5                    0.000000                 0.000000
# ...                           ...                      ...
# CDY1B                    0.000000                 0.000000
# CDY1                     0.000000                 0.000000
# CSPG4P1Y                 0.000000                 0.000000
# GOLGA2P3Y                0.000000                 0.000000
# GOLGA2P2Y                0.000000                 0.000000
#
#            Series9_NHBE_IFNB_12h_2  Promedio_Series9_NHBE_Mock  \
# DDX11L1                   0.000000                    0.000000
# WASH7P                    0.000727                    0.001278
# FAM138A                   0.000000                    0.000000
# FAM138F                   0.000000                    0.000000
# OR4F5                     0.000000                    0.000000
# ...                            ...                         ...
# CDY1B                     0.000000                    0.000000
# CDY1                      0.000000                    0.000000
# CSPG4P1Y                  0.000000                    0.000000
# GOLGA2P3Y                 0.000000                    0.000000
# GOLGA2P2Y                 0.000000                    0.000000
#
#            Promedio_Series9_NHBE_IFNB_4h  Promedio_Series9_NHBE_IFNB_6h  \
# DDX11L1                          0.00000                       0.000000
# WASH7P                           0.00089                       0.000783
# FAM138A                          0.00000                       0.000000
# FAM138F                          0.00000                       0.000000
# OR4F5                            0.00000                       0.000000
# ...                                  ...                            ...
# CDY1B                            0.00000                       0.000000
# CDY1                             0.00000                       0.000000
# CSPG4P1Y                         0.00000                       0.000000
# GOLGA2P3Y                        0.00000                       0.000000
# GOLGA2P2Y                        0.00000                       0.000000
#
#            Promedio_Series9_NHBE_IFNB_12h fold-change Series9 NHBE IFNB 4h  \
# DDX11L1                           0.00000                                0
# WASH7P                            0.00082                        -0.521924
# FAM138A                           0.00000                                0
# FAM138F                           0.00000                                0
# OR4F5                             0.00000                                0
# ...                                   ...                              ...
# CDY1B                             0.00000                                0
# CDY1                              0.00000                                0
# CSPG4P1Y                          0.00000                                0
# GOLGA2P3Y                         0.00000                                0
# GOLGA2P2Y                         0.00000                                0
#
#           fold-change Series9 NHBE IFNB 6h fold-change Series9 NHBE IFNB 12h
# DDX11L1                                  0                                 0
# WASH7P                           -0.706515                         -0.640084
# FAM138A                                  0                                 0
# FAM138F                                  0                                 0
# OR4F5                                    0                                 0
# ...                                    ...                               ...
# CDY1B                                    0                                 0
# CDY1                                     0                                 0
# CSPG4P1Y                                 0                                 0
# GOLGA2P3Y                                0                                 0
# GOLGA2P2Y                                0                                 0
#
# [21797 rows x 17 columns]

# %%
#CONJUNTO TOTAL
for key in Series.keys():
    Data = pd.concat([Data, Series[key].filter(like="Promedio_Series", axis=1)], axis=1)
    Data = pd.concat([Data, Series[key].filter(like="fold-change", axis=1)], axis=1)

# %%
#DF fold-change
fold_change_data = Data.filter(like='fold-change')

# %%
fold_change_data
# Out:
#           fold-change Series1 fold-change Series2 fold-change Series5  \
# DDX11L1                     0                 inf                   0
# WASH7P               0.093266            -0.13952            0.038719
# FAM138A                     0                   0                   0
# FAM138F                     0                   0                   0
# OR4F5                       0                   0                   0
# ...                       ...                 ...                 ...
# CDY1B                       0                   0                   0
# CDY1                        0                   0                   0
# CSPG4P1Y                    0                   0                   0
# GOLGA2P3Y                   0                   0                   0
# GOLGA2P2Y                   0                   0                   0
#
#           fold-change Series6 fold-change Series7  \
# DDX11L1                     0                 inf
# WASH7P                0.11719            0.295358
# FAM138A                     0                   0
# FAM138F                     0                   0
# OR4F5                       0                   0
# ...                       ...                 ...
# CDY1B                       0                   0
# CDY1                        0                   0
# CSPG4P1Y                    0                   0
# GOLGA2P3Y                   0                   0
# GOLGA2P2Y                   0                   0
#
#           fold-change Series9 NHBE IFNB 4h fold-change Series9 NHBE IFNB 6h  \
# DDX11L1                                  0                                0
# WASH7P                           -0.521924                        -0.706515
# FAM138A                                  0                                0
# FAM138F                                  0                                0
# OR4F5                                    0                                0
# ...                                    ...                              ...
# CDY1B                                    0                                0
# CDY1                                     0                                0
# CSPG4P1Y                                 0                                0
# GOLGA2P3Y                                0                                0
# GOLGA2P2Y                                0                                0
#
#           fold-change Series9 NHBE IFNB 12h fold-change Series15  \
# DDX11L1                                   0                    0
# WASH7P                            -0.640084                  inf
# FAM138A                                   0                    0
# FAM138F                                   0                    0
# OR4F5                                     0                    0
# ...                                     ...                  ...
# CDY1B                                     0                    0
# CDY1                                      0                    0
# CSPG4P1Y                                  0                    0
# GOLGA2P3Y                                 0                    0
# GOLGA2P2Y                                 0                    0
#
#           fold-change Series16 A549-ACE2 SARS-CoV-2  \
# DDX11L1                                           0
# WASH7P                                     2.565829
# FAM138A                                           0
# FAM138F                                           0
# OR4F5                                             0
# ...                                             ...
# CDY1B                                             0
# CDY1                                              0
# CSPG4P1Y                                          0
# GOLGA2P3Y                                         0
# GOLGA2P2Y                                         0
#
#           fold-change Series16 A549-ACE2 SARS-CoV-2 Rux
# DDX11L1                                               0
# WASH7P                                         2.894956
# FAM138A                                               0
# FAM138F                                               0
# OR4F5                                                 0
# ...                                                 ...
# CDY1B                                                 0
# CDY1                                                  0
# CSPG4P1Y                                              0
# GOLGA2P3Y                                             0
# GOLGA2P2Y                                             0
#
# [21797 rows x 11 columns]

# %%
missing_genes = Genes-set(fold_change_data.index)
fold_change_data = pd.DataFrame(fold_change_data, index=list(fold_change_data.index)+list(missing_genes), columns=fold_change_data.columns)

# %%
fold_change_data
# Out:
#           fold-change Series1 fold-change Series2 fold-change Series5  \
# DDX11L1                     0                 inf                   0
# WASH7P               0.093266            -0.13952            0.038719
# FAM138A                     0                   0                   0
# FAM138F                     0                   0                   0
# OR4F5                       0                   0                   0
# ...                       ...                 ...                 ...
# GOLGA2P3Y                   0                   0                   0
# GOLGA2P2Y                   0                   0                   0
# CR                        NaN                 NaN                 NaN
# DHNTP                     NaN                 NaN                 NaN
# ALPPL2                    NaN                 NaN                 NaN
#
#           fold-change Series6 fold-change Series7  \
# DDX11L1                     0                 inf
# WASH7P                0.11719            0.295358
# FAM138A                     0                   0
# FAM138F                     0                   0
# OR4F5                       0                   0
# ...                       ...                 ...
# GOLGA2P3Y                   0                   0
# GOLGA2P2Y                   0                   0
# CR                        NaN                 NaN
# DHNTP                     NaN                 NaN
# ALPPL2                    NaN                 NaN
#
#           fold-change Series9 NHBE IFNB 4h fold-change Series9 NHBE IFNB 6h  \
# DDX11L1                                  0                                0
# WASH7P                           -0.521924                        -0.706515
# FAM138A                                  0                                0
# FAM138F                                  0                                0
# OR4F5                                    0                                0
# ...                                    ...                              ...
# GOLGA2P3Y                                0                                0
# GOLGA2P2Y                                0                                0
# CR                                     NaN                              NaN
# DHNTP                                  NaN                              NaN
# ALPPL2                                 NaN                              NaN
#
#           fold-change Series9 NHBE IFNB 12h fold-change Series15  \
# DDX11L1                                   0                    0
# WASH7P                            -0.640084                  inf
# FAM138A                                   0                    0
# FAM138F                                   0                    0
# OR4F5                                     0                    0
# ...                                     ...                  ...
# GOLGA2P3Y                                 0                    0
# GOLGA2P2Y                                 0                    0
# CR                                      NaN                  NaN
# DHNTP                                   NaN                  NaN
# ALPPL2                                  NaN                  NaN
#
#           fold-change Series16 A549-ACE2 SARS-CoV-2  \
# DDX11L1                                           0
# WASH7P                                     2.565829
# FAM138A                                           0
# FAM138F                                           0
# OR4F5                                             0
# ...                                             ...
# GOLGA2P3Y                                         0
# GOLGA2P2Y                                         0
# CR                                              NaN
# DHNTP                                           NaN
# ALPPL2                                          NaN
#
#           fold-change Series16 A549-ACE2 SARS-CoV-2 Rux
# DDX11L1                                               0
# WASH7P                                         2.894956
# FAM138A                                               0
# FAM138F                                               0
# OR4F5                                                 0
# ...                                                 ...
# GOLGA2P3Y                                             0
# GOLGA2P2Y                                             0
# CR                                                  NaN
# DHNTP                                               NaN
# ALPPL2                                              NaN
#
# [21800 rows x 11 columns]

# %%
import numpy as np
a =np.full(list(missing_genes))
a.shape =(3,1)

# %%
np.array(missing_genes)
# Out:
# array({'CR', 'DHNTP', 'ALPPL2'}, dtype=object)
